# %%
import numpy as np
import pandas as pd
import cufflinks as cf

# %%
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

# %%
tls.set_credentials_file(username='dubeya', api_key='3sUyVZCvIjWDzsQYfThK')

# %%
df = pd.read_csv("Nightingale_csv.csv")

# %%
df
# Out:
#        Month  Average size of army  Zymotic diseases  Wounds & injuries  \
# 0   Apr 1854                  8571                 1                  0
# 1   May 1854                 23333                12                  0
# 2   Jun 1854                 28333                11                  0
# 3   Jul 1854                 28722               359                  0
# 4   Aug 1854                 30246               828                  1
# 5   Sep 1854                 30290               788                 81
# 6   Oct 1854                 30643               503                132
# 7   Nov 1854                 29736               844                287
# 8   Dec 1854                 32779              1725                114
# 9   Jan 1855                 32393              2761                 83
# 10  Feb 1855                 30919              2120                 42
# 11  Mar 1855                 30107              1205                 32
# ...

# %%
data1=df.iloc[0:12]
data2=df.iloc[12:24]

# %%
data1
# Out:
#        Month  Average size of army  Zymotic diseases  Wounds & injuries  \
# 0   Apr 1854                  8571                 1                  0
# 1   May 1854                 23333                12                  0
# 2   Jun 1854                 28333                11                  0
# 3   Jul 1854                 28722               359                  0
# 4   Aug 1854                 30246               828                  1
# 5   Sep 1854                 30290               788                 81
# 6   Oct 1854                 30643               503                132
# 7   Nov 1854                 29736               844                287
# 8   Dec 1854                 32779              1725                114
# 9   Jan 1855                 32393              2761                 83
# 10  Feb 1855                 30919              2120                 42
# 11  Mar 1855                 30107              1205                 32
#
# ...

# %%
data2
# Out:
#        Month  Average size of army  Zymotic diseases  Wounds & injuries  \
# 12  Apr 1855                 32252               477                 48
# 13  May 1855                 35473               508                 49
# 14  Jun 1855                 38863               802                209
# 15  Jul 1855                 42647               382                134
# 16  Aug 1855                 44614               483                164
# 17  Sep 1855                 47751               189                276
# 18  Oct 1855                 46852               128                 53
# 19  Nov 1855                 37853               178                 33
# 20  Dec 1855                 43217                91                 18
# 21  Jan 1856                 44212                42                  2
# 22  Feb 1856                 43485                24                  0
# 23  Mar 1856                 46140                15                  0
#
# ...

# %%
trace1 = go.Barpolar(
    r=data1[['Zymotic diseases']],
    text=['April-1854','May-1854','June-1854','July-1854','August-1854','September-1854','October-1854','November-1854','December-1854', 'January-1855', 'February-1855','March-1855'],
    name='Zymotic diseases',marker=dict(color='rgb(106,81,163)')
)

# %%
trace2 = go.Barpolar(
    r=data1[['Wounds & injuries']],
    text=['April-1854','May-1854','June-1854','July-1854','August-1854','September-1854','October-1854','November-1854','December-1854', 'January-1855', 'February-1855','March-1855'],
    name='Wounds & injuries',
    marker=dict(color='rgb(158,154,200)')
)

# %%
trace3 = go.Barpolar(
    r=data1[['All other causes']],
    text=['April-1854','May-1854','June-1854','July-1854','August-1854','September-1854','October-1854','November-1854','December-1854', 'January-1855', 'February-1855','March-1855'],
    name='All other causes',
    marker=dict(color='rgb(203,201,226)')
)

# %%
data = [trace1,trace2,trace3]
layout = go.Layout(
    title='APR 1854 to MAR 1855',
    font=dict(
        size=16
    ),
    legend=dict(
        font=dict(
            size=16
        )
    ),
    #radialaxis=dict(
     #   ticksuffix='%'
    #),
    orientation=270
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='wind-chart1')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~dubeya/0 or inside your plot.ly account where it is named 'wind-chart1'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~dubeya/0.embed" height="525px" width="100%"></iframe>

# %%
trace4 = go.Barpolar(
    r=data2[['Zymotic diseases']],
    text=['April-1855','May-1855','June-1855','July-1855','August-1855','September-1855','October-1855','November-1855','December-1855', 'January-1856', 'February-1856','March-1856'],
    name='Zymotic diseases',
    marker=dict(color='rgb(106,81,163)')
)
trace5 = go.Barpolar(
    r=data2[['Wounds & injuries']],
    text=['April-1855','May-1855','June-1855','July-1855','August-1855','September-1855','October-1855','November-1855','December-1855', 'January-1856', 'February-1856','March-1856'],
    name='Wounds & injuries',
    marker=dict(color='rgb(158,154,200)')
)
trace6 = go.Barpolar(
    r=data2[['All other causes']],
    text=['April-1855','May-1855','June-1855','July-1855','August-1855','September-1855','October-1855','November-1855','December-1855', 'January-1856', 'February-1856','March-1856'],
    name='All other causes',
    marker=dict(color='rgb(203,201,226)')
)

# %%
data = [trace4,trace5,trace6]
layout = go.Layout(
    title='APR 1855 to MAR 1856',
    font=dict(
        size=16
    ),
    legend=dict(
        font=dict(
            size=16
        )
    ),
    orientation=270
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='wind-chart-2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~dubeya/2.embed" height="525px" width="100%"></iframe>
